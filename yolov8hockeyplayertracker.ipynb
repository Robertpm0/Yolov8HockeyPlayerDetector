# %%
# !pip uninstall ultralytics -y
# !pip uninstall roboflow -y
# Out:
# WARNING: Skipping ultralytics as it is not installed.
# WARNING: Skipping roboflow as it is not installed.

# %%
# !pip install ultralytics==8.0.196
# Out:
# Collecting ultralytics==8.0.196
#   Downloading ultralytics-8.0.196-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (3.7.5)
# Requirement already satisfied: numpy>=1.22.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (4.10.0.82)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (4.66.4)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (0.12.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.0.196) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics==8.0.196)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.0.196) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.0.196) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.0.196) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.0.196) (2024.3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.0.196) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.0.196) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics==8.0.196) (1.3.0)
# Downloading ultralytics-8.0.196-py3-none-any.whl (631 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 kB 11.8 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.196

# %%
#!pip install ultralytics
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.33-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from roboflow) (2024.2.2)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from roboflow) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/conda/lib/python3.10/site-packages (from roboflow) (1.26.18)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/conda/lib/python3.10/site-packages (from roboflow) (4.66.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /opt/conda/lib/python3.10/site-packages (from roboflow) (0.10.1)
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.33-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.0 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 34.3 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Installing collected packages: python-magic, opencv-python-headless, idna, chardet, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.10.0.82
#     Uninstalling opencv-python-headless-4.10.0.82:
#       Successfully uninstalled opencv-python-headless-4.10.0.82
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# jupyterlab 4.2.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.3.3 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed chardet-4.0.0 idna-3.7 opencv-python-headless-4.10.0.84 python-magic-0.4.27 roboflow-1.1.33

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ykUtbJXSC5kVDDGBhzH2")
project = rf.workspace("hawkey").project("hockeyplayerdetectors")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in hockeyPlayerDetectors-1 to yolov8:: 100%|██████████| 143536/143536 [00:03<00:00, 42899.96it/s]
# Extracting Dataset Version Zip to hockeyPlayerDetectors-1 in yolov8:: 100%|██████████| 3488/3488 [00:00<00:00, 5596.69it/s]

# %%
# import shutil

# shutil.move('hockeyPlayerDetectors-1/train',
#             'hockeyPlayerDetectors-1/hockeyPlayerDetectors-1/train'
#             )

# shutil.move('hockeyPlayerDetectors-1/test',
#             'hockeyPlayerDetectors-1/hockeyPlayerDetectors-1/test'
#             )

# shutil.move('hockeyPlayerDetectors-1/valid',
#             'hockeyPlayerDetectors-1/hockeyPlayerDetectors-1/valid'
#             )

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|█████████████████████████████████████████| 131M/131M [00:00<00:00, 256MB/s]
# New https://pypi.org/project/ultralytics/8.2.40 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# engine/trainer: task=detect, mode=train, model=yolov8x.pt, data=/kaggle/working/hockeyPlayerDetectors-1/data.yaml, epochs=100, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 14.4MB/s]
# 2024-06-23 18:08:15.008737: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-23 18:08:15.008879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-23 18:08:15.145432: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8718931  ultralytics.nn.modules.head.Detect           [1, [320, 640, 640]]
# Model summary: 365 layers, 68153571 parameters, 68153555 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# wandb: Tracking run with wandb version 0.17.0
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 72.7MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/hockeyPlayerDetectors-1/train/labels... 1426 ima
# train: New cache created: /kaggle/working/hockeyPlayerDetectors-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/hockeyPlayerDetectors-1/valid/labels... 192 images
# val: New cache created: /kaggle/working/hockeyPlayerDetectors-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      16.1G     0.8499      0.796     0.9433         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.626      0.813      0.666      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      16.3G     0.9293     0.5893     0.9884         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.898       0.88      0.932      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      16.4G     0.9272     0.5783     0.9946         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.858       0.89      0.922      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      16.6G     0.9195     0.5644     0.9848         47        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.92      0.934      0.957      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      16.3G     0.8998     0.5405     0.9717         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.906      0.928       0.96      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      16.6G     0.8541     0.5074     0.9596         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.941      0.925       0.97      0.769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      16.6G     0.8569     0.5054     0.9582         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.922       0.94      0.973       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      16.5G     0.8069     0.4801      0.942         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.927      0.932      0.968      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      15.9G     0.7658     0.4669     0.9299         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.917      0.955      0.974      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      16.6G     0.7408     0.4525     0.9216         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.93      0.941      0.974       0.81
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      16.5G     0.6951     0.4247     0.9084         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.933      0.954      0.982      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      16.4G     0.6858     0.4149     0.9056         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.929      0.958      0.979      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      13.8G     0.6762     0.4124     0.9034         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.929      0.954      0.979      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      14.1G     0.6618     0.4092     0.9009         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.935      0.958      0.979      0.839
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      14.2G     0.6646     0.4098     0.8989         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.93      0.952      0.981      0.809
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      14.2G     0.6364     0.3947     0.8947         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.936      0.956      0.982      0.844
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      14.2G     0.6399     0.3991     0.8981         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.938      0.955       0.98      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      14.2G     0.6226     0.3925     0.8875         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.927      0.966      0.981      0.849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      14.2G     0.6075     0.3786      0.889         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.926      0.962       0.98      0.852
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      14.1G      0.604     0.3742     0.8842         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.932      0.955      0.979      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      14.2G     0.6045     0.3724     0.8827         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.938       0.96      0.978      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      14.2G     0.5913     0.3655     0.8764         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.941      0.948      0.982      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      14.2G     0.5909     0.3631     0.8787         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.926      0.968       0.98      0.846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      14.2G     0.5813       0.36       0.88         17        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.937       0.95       0.98      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      14.2G     0.5755     0.3525     0.8678         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.935      0.964      0.982      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      14.2G     0.5739     0.3552     0.8727         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.929      0.964      0.981      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      14.2G     0.5595     0.3484     0.8686         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.934      0.966      0.985      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      14.2G     0.5573     0.3462      0.869         10        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.959      0.981      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      14.2G     0.5656     0.3538     0.8671         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.925      0.973      0.983      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      14.2G     0.5481     0.3412      0.866         12        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.954      0.982      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      14.2G     0.5657     0.3516     0.8669         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.936      0.967      0.984      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      14.1G     0.5503     0.3408      0.866         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.961      0.982      0.867
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      14.2G     0.5474     0.3377     0.8658         15        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.959      0.984      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      14.2G      0.537      0.333     0.8633          7        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.951      0.945      0.983      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      14.2G     0.5371      0.331     0.8643         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.927      0.971      0.978      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      14.2G      0.524     0.3292     0.8554         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.958      0.981       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      14.2G     0.5281      0.327     0.8599         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.933      0.964      0.981      0.877
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      14.2G     0.5199     0.3235     0.8571         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.931      0.969      0.978      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      14.2G     0.5182     0.3201     0.8543         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.942      0.957      0.982      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      14.2G      0.513     0.3183     0.8555         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.958      0.984      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      14.2G     0.5141     0.3153     0.8496         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.931      0.978      0.983      0.877
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      14.1G     0.5075     0.3145     0.8526         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.938      0.968      0.983      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      14.2G     0.5135     0.3118      0.853         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.941      0.963      0.984      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      14.1G     0.4954     0.3079     0.8491         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.937       0.96       0.98      0.878
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      14.2G     0.4951     0.3067     0.8461         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.942      0.967      0.983      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      14.1G     0.4992     0.3072     0.8471         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.936      0.969      0.982      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      14.2G     0.4913     0.3019     0.8496         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.942      0.958      0.979       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      14.2G     0.4827     0.3002     0.8454         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.941      0.967      0.983      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      14.2G     0.4919     0.3019     0.8466         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.961      0.982      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      14.2G     0.4765     0.2936     0.8433         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.965      0.984      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      14.2G     0.4881     0.2996     0.8438         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.947      0.961      0.983      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      14.2G     0.4873     0.2999     0.8478         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.959      0.981      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      14.2G     0.4704      0.293     0.8428         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.937      0.965      0.984      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      14.2G     0.4663     0.2862     0.8366         19        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.971      0.984      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      14.2G     0.4709      0.288     0.8379         20        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.935      0.963      0.983      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      14.2G     0.4663     0.2859     0.8362         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.94      0.961       0.98      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      14.1G     0.4587     0.2796     0.8338         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.94       0.96      0.983      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      14.2G     0.4616     0.2859     0.8378         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.951      0.961      0.982       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      14.2G     0.4572     0.2797     0.8398         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.966      0.983      0.893
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      14.1G      0.459     0.2809     0.8364         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.958      0.983      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      14.2G     0.4537     0.2803     0.8353         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.971       0.98      0.888
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      14.1G     0.4461     0.2759     0.8341         70        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.94      0.967      0.983      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      14.2G     0.4493     0.2736     0.8345         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.936      0.973      0.982      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      14.1G     0.4401     0.2699     0.8317         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.936      0.967      0.983       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      14.2G     0.4427     0.2711      0.832         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.966      0.981      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      14.1G     0.4376     0.2675     0.8302         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.94      0.965      0.982      0.886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      14.2G     0.4356     0.2673     0.8302         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.941      0.973      0.982      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      14.1G     0.4382     0.2682     0.8284         16        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.942      0.966      0.982      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      14.1G     0.4314     0.2629     0.8282         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.967      0.982      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      14.2G     0.4318     0.2581     0.8245         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.94      0.973      0.981      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      14.2G      0.421     0.2552     0.8262         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.951       0.96      0.983      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      14.2G     0.4283     0.2589     0.8277         23        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.948       0.96      0.982      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      14.2G     0.4238     0.2557     0.8249         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.968       0.98      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      14.2G     0.4184     0.2535     0.8258         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.968      0.979      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      14.2G     0.4179      0.252     0.8279         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.963      0.982      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      14.2G     0.4171     0.2522     0.8237         47        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.947      0.964       0.98      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      14.2G     0.4056     0.2467     0.8214         17        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.946      0.963      0.982      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      14.2G     0.4027     0.2445     0.8225         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.946      0.964      0.981        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      14.2G     0.4086     0.2446     0.8231         44        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.937      0.966       0.98      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      14.2G     0.4015     0.2415     0.8209         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.95      0.954      0.981      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      14.2G     0.4016     0.2396     0.8214         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.966      0.979      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      14.2G     0.3959     0.2363     0.8209         15        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630       0.95      0.963       0.98      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      14.2G     0.3973     0.2391     0.8191         34        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.941      0.956      0.981      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      14.1G     0.3933     0.2362     0.8165         33        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.942      0.959      0.981      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      14.2G     0.3953     0.2361     0.8183         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.937      0.965      0.982      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      14.2G     0.3912      0.233     0.8163         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.947      0.956      0.979      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      14.2G     0.3874     0.2299      0.819         16        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.949      0.956      0.981      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      14.2G     0.3877     0.2281     0.8176         14        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.961       0.98      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      14.2G     0.3788     0.2256     0.8172         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.942      0.958       0.98      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      14.1G     0.3809     0.2229     0.8153         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.939      0.969      0.978      0.901
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      14.2G     0.3514     0.2056     0.8009         17        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.956      0.952       0.98      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      14.2G      0.351     0.2057     0.8023         19        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.932       0.97       0.98      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      14.2G     0.3446     0.2018     0.8003         19        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.952       0.95      0.981      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      14.2G     0.3358     0.1986     0.7961         17        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.936      0.963      0.979      0.899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      14.2G     0.3325     0.1941     0.7964         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.945      0.955       0.98      0.899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      14.2G     0.3361     0.1989     0.7946         13        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.944      0.964      0.978      0.899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      14.2G     0.3283     0.1918     0.7962         18        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.966      0.979      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      14.2G     0.3255     0.1907     0.7957         14        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.946       0.96      0.979      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      14.2G      0.321     0.1884     0.7924         11        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.946      0.961      0.979      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      14.2G     0.3209     0.1851     0.7937         15        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.954      0.955      0.979        0.9
#
# 100 epochs completed in 3.556 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 136.7MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 136.7MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        192       1630      0.943      0.966      0.979      0.903
# Speed: 0.1ms preprocess, 14.9ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/train
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 ▃████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  lr/pg1 ▃████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  lr/pg2 ▃████▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:        metrics/mAP50(B) ▁▇██████████████████████████████████████
# wandb:     metrics/mAP50-95(B) ▁▄▆▆▇▆▇▇▇▇▇▇▇█▇█████████████████████████
# wandb:    metrics/precision(B) ▁▆█▇███▇█▇██████████████████████████████
# wandb:       metrics/recall(B) ▁▄▆▆▇▇▇█▇█▇▇█▇▇▇█▇█▇▇█▇█████▇█▇▇▇▇▇▇█▇▇▇
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:          train/box_loss ▇█▇▇▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:          train/cls_loss █▆▅▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁
# wandb:          train/dfl_loss ▆█▇▆▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            val/box_loss ▆█▆▅▄▄▃▃▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/cls_loss █▅▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:            val/dfl_loss ▆█▅▄▃▃▃▂▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 6e-05
# wandb:                  lr/pg1 6e-05
# wandb:                  lr/pg2 6e-05
# wandb:        metrics/mAP50(B) 0.97875
# wandb:     metrics/mAP50-95(B) 0.90284
# wandb:    metrics/precision(B) 0.94253
# wandb:       metrics/recall(B) 0.96597
# wandb:            model/GFLOPs 258.123
# wandb:        model/parameters 68153571
# wandb: model/speed_PyTorch(ms) 14.778
# wandb:          train/box_loss 0.32088
# wandb:          train/cls_loss 0.18511
# wandb:          train/dfl_loss 0.79366
# wandb:            val/box_loss 0.44376
# wandb:            val/cls_loss 0.27535
# wandb:            val/dfl_loss 0.84304
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /kaggle/working/wandb/offline-run-20240623_180828-nyjitt3t
# wandb: Find logs at: ./wandb/offline-run-20240623_180828-nyjitt3t/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train
